# %%
import pandas as pd
import numpy as np

# %%
parquet_file='/content/train.parquet'

train_data=pd.read_parquet(parquet_file)

train_data.shape
# Out:
# (3220868, 3)

# %%
train_data["Date"] = pd.to_datetime(train_data["Date"] )

# %%
new_data = train_data.drop_duplicates()
new_data = new_data.loc[~new_data.index.duplicated(), :]

# %%
new_data['Period'] = new_data.groupby(["Patient-Uid","Incident"])["Date"].diff().abs()
new_data.dropna()
# Out:
#                                    Patient-Uid       Date      Incident  \
# 56        a0dc9ad3-1c7c-11ec-b5b9-16262ee38c7f 2019-08-16   DRUG_TYPE_0
# 105       a0dca045-1c7c-11ec-9347-16262ee38c7f 2019-04-18   TEST_TYPE_0
# 131       a0dca166-1c7c-11ec-b745-16262ee38c7f 2018-07-01   DRUG_TYPE_9
# 167       a0dca551-1c7c-11ec-8acc-16262ee38c7f 2016-09-08   DRUG_TYPE_6
# 266       a0dcad87-1c7c-11ec-92bc-16262ee38c7f 2016-12-18   DRUG_TYPE_1
# ...                                        ...        ...           ...
# 29080862  a0ee15ba-1c7c-11ec-81cb-16262ee38c7f 2016-12-08   DRUG_TYPE_2
# 29080886  a0ee9f75-1c7c-11ec-94c7-16262ee38c7f 2018-07-06   DRUG_TYPE_6
# 29080900  a0ee9b26-1c7c-11ec-8a40-16262ee38c7f 2018-10-18  DRUG_TYPE_10
# 29080903  a0ee1a92-1c7c-11ec-8341-16262ee38c7f 2015-09-18   DRUG_TYPE_6
# 29080911  a0ee146e-1c7c-11ec-baee-16262ee38c7f 2018-10-05   DRUG_TYPE_1
#
#            Period
# 56       422 days
# 105        1 days
# 131      577 days
# 167      273 days
# 266      211 days
# ...           ...
# 29080862 678 days
# 29080886 379 days
# 29080900 377 days
# 29080903 862 days
# 29080911 489 days
#
# [2710083 rows x 4 columns]

# %%
df=(new_data[new_data["Period"]<"40 days"])
df
# Out:
#                                    Patient-Uid       Date           Incident  \
# 105       a0dca045-1c7c-11ec-9347-16262ee38c7f 2019-04-18        TEST_TYPE_0
# 391       a0dca2c4-1c7c-11ec-add6-16262ee38c7f 2019-03-26  PRIMARY_DIAGNOSIS
# 476       a0dcbe50-1c7c-11ec-864f-16262ee38c7f 2020-02-24        DRUG_TYPE_0
# 519       a0dc9543-1c7c-11ec-bb63-16262ee38c7f 2016-05-24        DRUG_TYPE_1
# 553       a0dc9919-1c7c-11ec-8049-16262ee38c7f 2018-07-10  PRIMARY_DIAGNOSIS
# ...                                        ...        ...                ...
# 29075105  a0ebe423-1c7c-11ec-a5e0-16262ee38c7f 2019-07-02        TARGET DRUG
# 29076810  a0ebc404-1c7c-11ec-9de6-16262ee38c7f 2018-12-25        DRUG_TYPE_2
# 29076936  a0ec0bd6-1c7c-11ec-8822-16262ee38c7f 2016-07-01        DRUG_TYPE_2
# 29080089  a0ee1b1f-1c7c-11ec-9123-16262ee38c7f 2016-02-05        DRUG_TYPE_0
# 29080246  a0ee17c0-1c7c-11ec-a2bc-16262ee38c7f 2019-10-03        DRUG_TYPE_0
#
#           Period
# 105       1 days
# 391      10 days
# 476      36 days
# 519      25 days
# 553       4 days
# ...          ...
# 29075105 21 days
# 29076810 29 days
# 29076936 12 days
# 29080089 28 days
# 29080246 27 days
#
# [247168 rows x 4 columns]

# %%
#df.isna()

# %%
#df=df[pd.notnull(df['Period'])]

# %%
#df_mode=df.groupby(["Patient-Uid","Incident"])["Period"].aggregate(pd.Series.mode).to_frame()

# %%
#df_mode.head(10)

# %%
df['Period'] = df['Period'].dt.days.astype('int32')

# %%
df.head()
# Out:
#                               Patient-Uid       Date           Incident  \
# 105  a0dca045-1c7c-11ec-9347-16262ee38c7f 2019-04-18        TEST_TYPE_0
# 391  a0dca2c4-1c7c-11ec-add6-16262ee38c7f 2019-03-26  PRIMARY_DIAGNOSIS
# 476  a0dcbe50-1c7c-11ec-864f-16262ee38c7f 2020-02-24        DRUG_TYPE_0
# 519  a0dc9543-1c7c-11ec-bb63-16262ee38c7f 2016-05-24        DRUG_TYPE_1
# 553  a0dc9919-1c7c-11ec-8049-16262ee38c7f 2018-07-10  PRIMARY_DIAGNOSIS
#
#      Period
# 105       1
# 391      10
# 476      36
# 519      25
# 553       4

# %%
type(df['Period'])
# Out:
# pandas.core.series.Series

# %%
 df['op']=df['Period'].apply(lambda x: 1 if x >= 28 and x <= 32 else 0)
 df
# Out:
#                                    Patient-Uid       Date           Incident  \
# 105       a0dca045-1c7c-11ec-9347-16262ee38c7f 2019-04-18        TEST_TYPE_0
# 391       a0dca2c4-1c7c-11ec-add6-16262ee38c7f 2019-03-26  PRIMARY_DIAGNOSIS
# 476       a0dcbe50-1c7c-11ec-864f-16262ee38c7f 2020-02-24        DRUG_TYPE_0
# 519       a0dc9543-1c7c-11ec-bb63-16262ee38c7f 2016-05-24        DRUG_TYPE_1
# 553       a0dc9919-1c7c-11ec-8049-16262ee38c7f 2018-07-10  PRIMARY_DIAGNOSIS
# ...                                        ...        ...                ...
# 29075105  a0ebe423-1c7c-11ec-a5e0-16262ee38c7f 2019-07-02        TARGET DRUG
# 29076810  a0ebc404-1c7c-11ec-9de6-16262ee38c7f 2018-12-25        DRUG_TYPE_2
# 29076936  a0ec0bd6-1c7c-11ec-8822-16262ee38c7f 2016-07-01        DRUG_TYPE_2
# 29080089  a0ee1b1f-1c7c-11ec-9123-16262ee38c7f 2016-02-05        DRUG_TYPE_0
# 29080246  a0ee17c0-1c7c-11ec-a2bc-16262ee38c7f 2019-10-03        DRUG_TYPE_0
#
#           Period  op
# 105            1   0
# 391           10   0
# 476           36   0
# 519           25   0
# 553            4   0
# ...          ...  ..
# 29075105      21   0
# 29076810      29   1
# 29076936      12   0
# 29080089      28   1
# 29080246      27   0
#
# [247168 rows x 5 columns]

# %%
df.shape
# Out:
# (247168, 5)

# %%
df_mode=df.groupby(["Patient-Uid","Incident"])["op"].aggregate(pd.Series.mode).to_frame()
# Out:
#                                                        op
# Patient-Uid                          Incident
# a0db1e73-1c7c-11ec-ae39-16262ee38c7f DRUG_TYPE_0        0
#                                      DRUG_TYPE_6        0
#                                      DRUG_TYPE_7        0
#                                      DRUG_TYPE_8        0
#                                      PRIMARY_DIAGNOSIS  0

# %%
df_mode.head(10)
# Out:
#                                                             op
# Patient-Uid                          Incident
# a0db1e73-1c7c-11ec-ae39-16262ee38c7f DRUG_TYPE_0             0
#                                      DRUG_TYPE_6             0
#                                      DRUG_TYPE_7             0
#                                      DRUG_TYPE_8             0
#                                      PRIMARY_DIAGNOSIS       0
#                                      TEST_TYPE_0             1
# a0dc93f2-1c7c-11ec-9cd2-16262ee38c7f DRUG_TYPE_0             1
#                                      DRUG_TYPE_1             1
#                                      DRUG_TYPE_2             0
#                                      DRUG_TYPE_3        [0, 1]

# %% [markdown]
# def query_count(df_mode):
#     return df_mode.query('op' == 1).op.count()
# print(query_count(df_mode))

# %%
print(type(df_mode['op']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
count=0
for i in df_mode['op']:
  if i==1:
    count+=1
print(count)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-3e4d0ffe72e8> in <module>
#       1 count=0
#       2 for i in df_mode['op']:
# ----> 3   if i==1:
#       4     count+=1
#       5 print(count)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
#df.sort_values(by=['Country'])

df_code=df_mode.sort_values(by=['Patient-Uid'])
df_code
# Out:
#                                                             op
# Patient-Uid                          Incident
# a0db1e73-1c7c-11ec-ae39-16262ee38c7f DRUG_TYPE_0             0
#                                      DRUG_TYPE_6             0
#                                      DRUG_TYPE_7             0
#                                      DRUG_TYPE_8             0
#                                      PRIMARY_DIAGNOSIS       0
# ...                                                        ...
# a0f0d553-1c7c-11ec-a70a-16262ee38c7f DRUG_TYPE_3        [0, 1]
# a0f0d582-1c7c-11ec-a6c1-16262ee38c7f DRUG_TYPE_1             1
#                                      DRUG_TYPE_5             1
#                                      DRUG_TYPE_0             1
#                                      TARGET DRUG             0
#
# [123054 rows x 1 columns]

# %%
df_
# Out:
# Index(['op'], dtype='object')

# %%
df_mode['Patient_code'] = df_mode['Patient-Uid'].cat.codes
df_mode.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Patient-Uid'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-140-1f4598a6da3e> in <module>
# ----> 1 df_mode['Patient_code'] = df_mode['Patient-Uid'].cat.codes
#       2 df_mode.head()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Patient-Uid'

# %%
pd.get_dummies(df_mode, columns=['Patient-Uid']).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-141-a6cb65b4fc9a> in <module>
# ----> 1 pd.get_dummies(df_mode, columns=['Patient-Uid']).head()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     888             raise TypeError("Input must be a list-like for parameter `columns`")
#     889         else:
# --> 890             data_to_encode = data[columns]
#     891
#     892         # validate prefixes and separator to avoid silently dropping cols
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Patient-Uid'], dtype='object')] are in the [columns]"
